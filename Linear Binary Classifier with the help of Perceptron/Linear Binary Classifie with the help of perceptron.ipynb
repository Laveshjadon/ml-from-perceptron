# %%
from sklearn.datasets import make_classification
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X, y = make_classification(n_samples=1000,n_features=2, n_informative=2, n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=10)

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', edgecolor='k')

plt.show()

# %%
y[y == 0] = -1

# %%
def perceptron(X,y):
    
    w1=w2=b=1
    lr = 0.1
    
    for j in range(1000):
    
        for i in range(X.shape[0]):

            # check condition
            z = w1*X[i][0] + w2*X[i][1] + b

            if z*y[i] < 0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]
            
    return w1,w2,b

# %%
w1,w2,b = perceptron(X,y)

# %%
b
# Out:
# np.float64(0.9)

# %%
w1
# Out:
# np.float64(-0.018563445634735318)

# %%
w2
# Out:
# np.float64(-0.35621266080461556)

# %%
u = -(w1/w2)
v = -(b/w2)

print(u,v)
# Out:
# -0.05211337966709011 2.5265806048753965

# %%
x_input = np.linspace(X[:,0].min(), X[:,0].max(), 100)
y_input = -(w1 * x_input + b) / w2

plt.figure(figsize=(10,6))
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100, edgecolor='k')
plt.plot(x_input, y_input, color='red', linewidth=3, label='Perceptron Line')
plt.legend()
plt.ylim(X[:,1].min() - 1, X[:,1].max() + 1) # Zoom out slightly
plt.title(f"Perceptron Decision Boundary\nWeights: w1={w1:.2f}, w2={w2:.2f}, b={b:.2f}")
plt.show()
